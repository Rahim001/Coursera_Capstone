# %%
import pandas as pd
df_csv = pd.read_csv('Population.csv',encoding='iso8859_9',delimiter=';')
# Select your desired district in the filter.
df_csv =df_csv[df_csv.District=='Sarıyer'] 
df_csv.reset_index(drop=True)
# Out:
#         City District          Neighborhood  Population
# 0   Istanbul  Sarıyer               Ayazağa       34740
# 1   Istanbul  Sarıyer           Zekeriyaköy       18707
# 2   Istanbul  Sarıyer             Reşitpaşa       17902
# 3   Istanbul  Sarıyer               Tarabya       17724
# 4   Istanbul  Sarıyer               İstinye       15692
# 5   Istanbul  Sarıyer   Fatih Sultan Mehmet       15557
# 6   Istanbul  Sarıyer               Yeniköy       15218
# 7   Istanbul  Sarıyer            Ferahevler       14991
# 8   Istanbul  Sarıyer                 Maden       13260
# 9   Istanbul  Sarıyer        Sarıyer Merkez       12568
# 10  Istanbul  Sarıyer                 Pınar       11248
# 11  Istanbul  Sarıyer            Cumhuriyet       10887
# 12  Istanbul  Sarıyer          Rumelihisarı       10736
# 13  Istanbul  Sarıyer                Maslak        9567
# 14  Istanbul  Sarıyer           Darüşşafaka        9423
# 15  Istanbul  Sarıyer               Emirgan        8751
# 16  Istanbul  Sarıyer             Büyükdere        8719
# 17  Istanbul  Sarıyer            Uskumruköy        8482
# 18  Istanbul  Sarıyer                 Huzur        8020
# 19  Istanbul  Sarıyer  Kazım Karabekir Paşa        7998
# 20  Istanbul  Sarıyer            Kireçburnu        6986
# 21  Istanbul  Sarıyer               Poligon        6667
# 22  Istanbul  Sarıyer             Çamlıtepe        5950
# 23  Istanbul  Sarıyer            Ptt Evleri        5342
# 24  Istanbul  Sarıyer          Rumelifeneri        5208
# 25  Istanbul  Sarıyer         Bahçeköy Yeni        5135
# 26  Istanbul  Sarıyer           Baltalimanı        5122
# 27  Istanbul  Sarıyer             Çayırbaşı        4905
# 28  Istanbul  Sarıyer               Kocataş        4383
# 29  Istanbul  Sarıyer             Gümüşdere        3914
# 30  Istanbul  Sarıyer       Bahçeköy Merkez        3773
# 31  Istanbul  Sarıyer          Rumelikavağı        3722
# 32  Istanbul  Sarıyer                Kilyos        3465
# 33  Istanbul  Sarıyer                  Yeni        3400
# 34  Istanbul  Sarıyer        Bahçeköy Kemer        2296
# 35  Istanbul  Sarıyer            Demirciköy        1308
# 36  Istanbul  Sarıyer               Garipçe         387
# 37  Istanbul  Sarıyer             Kısırkaya         350

# %%
column_names = ['City','District','Neighborhood','Latitude', 'Longitude','Population'] 

# instantiate the dataframe
ıstanbul = pd.DataFrame(columns=column_names)
ıstanbul
# Out:
# Empty DataFrame
# Columns: [City, District, Neighborhood, Latitude, Longitude, Population]
# Index: []

# %%
from geopy.geocoders import Nominatim

for index, data in df_csv.iterrows():
    city = data['City']
    district = data['District']
    neighborhood = data['Neighborhood']
    population = data ['Population']
    address = district + ','+ neighborhood
    geolocator = Nominatim(user_agent="ny_explorer")
    location = geolocator.geocode(address)
    print(location)
    print('Loca: ', index)
    
    if location!=None:
        lat = location.latitude
        lon = location.longitude
        
    ıstanbul = ıstanbul.append({'City':city,
                                'District':district,
                                'Neighborhood':neighborhood,
                                'Latitude':lat,
                                'Longitude':lon,
                                'Population':population},ignore_index=True)
# Out:
# Ayazağa, Ayazağa Mahallesi, Sarıyer, İstanbul, Marmara Bölgesi, 
# 11  Istanbul  Sarıyer            Cumhuriyet  41.147831  29.034713      10887
# 12  Istanbul  Sarıyer          Rumelihisarı  41.088247  29.053549      10736
# 13  Istanbul  Sarıyer                Maslak  41.125482  29.015168       9567
# 14  Istanbul  Sarıyer           Darüşşafaka  41.123982  29.036477       9423
# 15  Istanbul  Sarıyer               Emirgan  41.103131  29.053689       8751
# 16  Istanbul  Sarıyer             Büyükdere  41.163973  29.042464       8719
# 17  Istanbul  Sarıyer            Uskumruköy  41.221405  29.023132       8482
# 18  Istanbul  Sarıyer                 Huzur  41.104210  28.999481       8020
# 19  Istanbul  Sarıyer  Kazım Karabekir Paşa  41.173568  29.016258       7998
# 20  Istanbul  Sarıyer            Kireçburnu  41.145974  29.046525       6986
# 21  Istanbul  Sarıyer               Poligon  41.116262  29.039758       6667
# 22  Istanbul  Sarıyer             Çamlıtepe  41.133318  29.031762       5950
# 23  Istanbul  Sarıyer            Ptt Evleri  41.155896  29.014141       5342
# 24  Istanbul  Sarıyer          Rumelifeneri  41.233404  29.110933       5208
# 25  Istanbul  Sarıyer         Bahçeköy Yeni  41.179273  28.996450       5135
# 26  Istanbul  Sarıyer           Baltalimanı  41.095558  29.052582       5122
# 27  Istanbul  Sarıyer             Çayırbaşı  41.158720  29.032600       4905
# 28  Istanbul  Sarıyer               Kocataş  41.168930  29.035260       4383
# 29  Istanbul  Sarıyer             Gümüşdere  41.236736  28.985106       3914
# 30  Istanbul  Sarıyer       Bahçeköy Merkez  41.178003  28.991307       3773
# 31  Istanbul  Sarıyer          Rumelikavağı  41.178003  28.991307       3722
# 32  Istanbul  Sarıyer                Kilyos  41.245770  29.036500       3465
# 33  Istanbul  Sarıyer                  Yeni  41.179273  28.996450       3400
# 34  Istanbul  Sarıyer        Bahçeköy Kemer  41.168456  28.990292       2296
# 35  Istanbul  Sarıyer            Demirciköy  41.233733  29.061662       1308
# 36  Istanbul  Sarıyer               Garipçe  41.214791  29.108540        387
# 37  Istanbul  Sarıyer             Kısırkaya  41.251854  28.977451        350

# %%
# Sarıyer District - Get Geo Locatiın
address = 'Sarıyer, Istanbul'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate are 41.1662744, 29.0306735.

# %%
# create map of Manhattan using latitude and longitude values
import folium 
map_br = folium.Map(location=[latitude, longitude], zoom_start=11)

# add markers to map
for lat, lng, label in zip(ıstanbul_br['Latitude'], ıstanbul_br['Longitude'], ıstanbul_br['Neighborhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_br)  
    
map_br
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
CLIENT_ID = 'FX1WILAUZNRBMVAKSSZOIOE1Y5THUIU5XX1BAIGHYHYLI5H4' # your Foursquare ID
CLIENT_SECRET = 'AA0ROBLEZPKMRMTIZOKHSCTMNBDV0PIYYLB4O3EUIPYCQ2QO' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: FX1WILAUZNRBMVAKSSZOIOE1Y5THUIU5XX1BAIGHYHYLI5H4
# CLIENT_SECRET:AA0ROBLEZPKMRMTIZOKHSCTMNBDV0PIYYLB4O3EUIPYCQ2QO

# %%
# Search any neigbprhood ... 
neighborhood_latitude = ıstanbul_br.loc[13, 'Latitude'] # neighborhood latitude value
neighborhood_longitude = ıstanbul_br.loc[13, 'Longitude'] # neighborhood longitude value

neighborhood_name = ıstanbul_br.loc[13, 'Neighborhood'] # neighborhood name

print('Latitude and longitude values of {} are {}, {}.'.format(neighborhood_name, 
                                                               neighborhood_latitude, 
                                                               neighborhood_longitude))
# Out:
# Latitude and longitude values of Maslak are 41.1254819, 29.0151681.

# %%
search_query = 'Gym'
LIMIT = 150
radius = 1200
url = 'https://api.foursquare.com/v2/venues/search?&client_id={}&client_secret={}&v={}&query={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    search_query,
    neighborhood_latitude, 
    neighborhood_longitude, 
    radius, 
    LIMIT)
url # display URL
# Out:
# 'https://api.foursquare.com/v2/venues/search?&client_id=FX1WILAUZNRBMVAKSSZOIOE1Y5THUIU5XX1BAIGHYHYLI5H4&client_secret=AA0ROBLEZPKMRMTIZOKHSCTMNBDV0PIYYLB4O3EUIPYCQ2QO&v=20180605&query=Gym&ll=41.1254819,29.0151681&radius=1200&limit=150'

# %%
import requests
from pandas.io.json import json_normalize
results = requests.get(url).json()

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d175941735', 'name': 'G...    False
# 1  [{'id': '4bf58dd8d48988d175941735', 'name': 'G...    False
# 2  [{'id': '4bf58dd8d48988d176941735', 'name': 'G...    False
# 3  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...    False
# 4                                                 []    False
#
#                          id                              location.address  \
# 0  5beefdf1e65d0c002c9f4b0c           Ağaoğlu Maslak 1453 NeoTech Kampüsü
# 1  5b5ad56ea5a315002c2cf912                                           NaN
# 2  51533002e4b0054683566223                                        Maslak
# 3  4fc7884fe4b0ed35a3e7ca4a  Darüşşafaka Mah. Derbent Mevkii Maslak Şişli
# 4  4ebfc14402d5a63a3f17de65                                           NaN
#
#   location.cc location.city location.country location.crossStreet  \
# 0          TR       Sarıyer          Türkiye  Maslak 1453 Caddesi
# 1          TR      İstanbul          Türkiye                  NaN
# 2          TR      İstanbul          Türkiye  Dereboyu Cad. No:16
# 3          TR      İstanbul          Türkiye                  NaN
# 4          TR      İstanbul          Türkiye                  NaN
#
#    location.distance                          location.formattedAddress  \
# 0               1040  [Ağaoğlu Maslak 1453 NeoTech Kampüsü (Maslak 1...
# 1                797                                [İstanbul, Türkiye]
# 2               1554  [Maslak (Dereboyu Cad. No:16), İstanbul, Türkiye]
# 3                834  [Darüşşafaka Mah. Derbent Mevkii Maslak Şişli,...
# 4               1079                          [34398 İstanbul, Türkiye]
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 41.117237, 'lng':...     41.117237
# 1  [{'label': 'display', 'lat': 41.120069, 'lng':...     41.120069
# 2  [{'label': 'display', 'lat': 41.11262926674827...     41.112629
# 3  [{'label': 'display', 'lat': 41.12677024253526...     41.126770
# 4  [{'label': 'display', 'lat': 41.11602150321616...     41.116022
#
#    location.lng location.postalCode location.state                       name  \
# 0     29.009320               34398       İstanbul  NishFit Gym & Sports Club
# 1     29.008941                 NaN       İstanbul               Somerset Gym
# 2     29.022418                 NaN       İstanbul       M-GYM Fitness Center
# 3     29.024975                 NaN       İstanbul                   Life Gym
# 4     29.018019               34398       İstanbul      D-Gym Relaxation Room
#
#      referralId
# 0  v-1563340250
# 1  v-1563340250
# 2  v-1563340250
# 3  v-1563340250
# 4  v-1563340250

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']


# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)


# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                    name            categories  \
# 0             NishFit Gym & Sports Club  Gym / Fitness Center
# 1                          Somerset Gym  Gym / Fitness Center
# 2                  M-GYM Fitness Center                   Gym
# 3                              Life Gym            Restaurant
# 4                 D-Gym Relaxation Room                  None
# 5                       Son Paravan Gym  Gym / Fitness Center
# 6                           Passife Gym        Gymnastics Gym
# 7             D-Gym Kapalı Yüzme Havuzu                  Pool
# 8                Aikidosever @ Life Gym     Martial Arts Dojo
# 9      Darüşşafaka Life Gym Balo Salonu       Other Nightlife
# 10                                M-GYM                   Gym
# 11                           HSBC M-Gym                   Gym
# 12  Darussafaka Life Gym Tenis Kortlari          Tennis Court
# 13                                M-GYM                   Gym
# 14                             HSBC GYM                   Gym
# 15                     Ceg Coaching GYM                   Gym
# 6   [{'label': 'display', 'lat': 41.11829771113135...  41.118298  29.025759
# 7   [{'label': 'display', 'lat': 41.114985, 'lng':...  41.114985  29.021835
# 8   [{'label': 'display', 'lat': 41.12561898696649...  41.125619  29.029453
# 9   [{'label': 'display', 'lat': 41.12546427563177...  41.125464  29.029868
# 10  [{'label': 'display', 'lat': 41.11264922889733...  41.112649  29.022321
# 11  [{'label': 'display', 'lat': 41.11220558031159...  41.112206  29.022634
# 12  [{'label': 'display', 'lat': 41.12594804192154...  41.125948  29.029970
# 13  [{'label': 'display', 'lat': 41.11247670351948...  41.112477  29.021865
# 14  [{'label': 'display', 'lat': 41.11256406702688...  41.112564  29.022616
# 15  [{'label': 'display', 'lat': 41.11373957591353...  41.113740  29.022282
# 16  [{'label': 'display', 'lat': 41.11536392821798...  41.115364  29.020555
# 17  [{'label': 'display', 'lat': 41.12019444997339...  41.120194  29.026356
#
#    postalCode     state                        id
# 0       34398  İstanbul  5beefdf1e65d0c002c9f4b0c
# 1         NaN  İstanbul  5b5ad56ea5a315002c2cf912
# 2         NaN  İstanbul  51533002e4b0054683566223
# 3         NaN  İstanbul  4fc7884fe4b0ed35a3e7ca4a
# 4       34398  İstanbul  4ebfc14402d5a63a3f17de65
# 5         NaN       NaN  56dd9900498e16de5d7a50f6
# 6         NaN       NaN  53271976498e56006d569b71
# 7         NaN       NaN  55111c9d498eb9342a5beebf
# 8         NaN       NaN  52f5ec87498e4575c2f0bac2
# 9         NaN       NaN  528fa02611d23de106ddf00e
# 10        NaN       NaN  520c5e3111d27a9cc46c5faf
# 11        NaN       NaN  53be1711498ed601ddd02c05
# 12      34457  İstanbul  50697994e4b05eea710bf1d0
# 13        NaN  İstanbul  4fb0d2f5c2ee3277061b9d2f
# 14        NaN       NaN  53160e8b498ebad957cd53cc
# 15        NaN  İstanbul  529ce3c711d2a009698d2136
# 16        NaN  İstanbul  4be1453a0365c9b68235b338
# 17        NaN       NaN  51c98c0b498e44cf9fc73f18

# %%
nearby_venues = dataframe_filtered[['name','categories','lat','lng']]

nearby_venues[(nearby_venues['categories'].str.contains("Gym")==True) & (nearby_venues['categories'].str.contains("gym")==True) & (nearby_venues['categories'].str.contains("sport")==True)]

nearby_venues.reset_index(drop=True)
# Out:
#                                    name            categories        lat  \
# 0             NishFit Gym & Sports Club  Gym / Fitness Center  41.117237
# 1                          Somerset Gym  Gym / Fitness Center  41.120069
# 2                  M-GYM Fitness Center                   Gym  41.112629
# 3                              Life Gym            Restaurant  41.126770
# 4                 D-Gym Relaxation Room                  None  41.116022
# 5                       Son Paravan Gym  Gym / Fitness Center  41.124084
# 6                           Passife Gym        Gymnastics Gym  41.118298
# 7             D-Gym Kapalı Yüzme Havuzu                  Pool  41.114985
# 8                Aikidosever @ Life Gym     Martial Arts Dojo  41.125619
# 9      Darüşşafaka Life Gym Balo Salonu       Other Nightlife  41.125464
# 10                                M-GYM                   Gym  41.112649
# 11                           HSBC M-Gym                   Gym  41.112206
# 12  Darussafaka Life Gym Tenis Kortlari          Tennis Court  41.125948
# 13                                M-GYM                   Gym  41.112477
# 14                             HSBC GYM                   Gym  41.112564
# 15                     Ceg Coaching GYM                   Gym  41.113740
# 16                               D-Cafe                  Café  41.115364
# 17   Darrusafaka Gymnasıum Sport Center              Gym Pool  41.120194
#
#           lng
# 0   29.009320
# 1   29.008941
# 2   29.022418
# 3   29.024975
# 4   29.018019
# 5   29.028776
# 6   29.025759
# 7   29.021835
# 8   29.029453
# 9   29.029868
# 10  29.022321
# 11  29.022634
# 12  29.029970
# 13  29.021865
# 14  29.022616
# 15  29.022282
# 16  29.020555
# 17  29.026356

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

# add a red circle marker to represent the Conrad Hotel
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Conrad Hotel',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=1200):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/search?&client_id={}&client_secret={}&v={}&query={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            search_query,
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        results = requests.get(url).json()['response']['venues']

            
        # make the GET request       
        venues_list.append([(
            name,
            v['name']) for v in results])
    
    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood','Gym']

    return(nearby_venues)

# %%
gym_venues = getNearbyVenues(names=ıstanbul_br['Neighborhood'],
                                   latitudes=ıstanbul_br['Latitude'],
                                   longitudes=ıstanbul_br['Longitude']
                                  )
# Out:
# Ayazağa
# Zekeriyaköy
# Reşitpaşa
# Tarabya
# İstinye
# Fatih Sultan Mehmet
# Yeniköy
# Ferahevler
# Maden
# Sarıyer Merkez
# Pınar
# Cumhuriyet
# Rumelihisarı
# Maslak
# Darüşşafaka
# Emirgan
# Büyükdere
# Uskumruköy
# Huzur
# Kazım Karabekir Paşa
# Kireçburnu
# Poligon
# Çamlıtepe
# Ptt Evleri
# Rumelifeneri
# Bahçeköy Yeni
# Baltalimanı
# Çayırbaşı
# Kocataş
# Gümüşdere
# Bahçeköy Merkez
# Rumelikavağı
# Kilyos
# Yeni
# Bahçeköy Kemer
# Demirciköy
# Garipçe
# Kısırkaya

# %%
#gym_venues
gym_venues[(gym_venues['Gym'].str.contains("Gym")==True) & (gym_venues['Gym'].str.contains("gym")==True) & (gym_venues['Gym'].str.contains("sport")==True)]

gym_venues=gym_venues.groupby('Neighborhood').count().reset_index()
gym_venues
# Out:
#             Neighborhood  Gym
# 0         Bahçeköy Kemer    6
# 1        Bahçeköy Merkez    7
# 2          Bahçeköy Yeni    7
# 3            Baltalimanı   16
# 4              Büyükdere    5
# 5             Cumhuriyet    9
# 6            Darüşşafaka   23
# 7             Demirciköy    1
# 8                Emirgan    1
# 9    Fatih Sultan Mehmet   25
# 10            Ferahevler   26
# 11                 Huzur   21
# 12  Kazım Karabekir Paşa    1
# 13                Kilyos    6
# 14            Kireçburnu    8
# 15               Kocataş    7
# 16                 Maden   11
# 17                Maslak   18
# 18               Poligon   24
# 19            Ptt Evleri    2
# 20                 Pınar   30
# 21             Reşitpaşa   11
# 22          Rumelihisarı   16
# 23          Rumelikavağı    7
# 24        Sarıyer Merkez    6
# 25               Tarabya   12
# 26            Uskumruköy    1
# 27                  Yeni    7
# 28               Yeniköy    4
# 29           Zekeriyaköy    5
# 30             Çamlıtepe   17
# 31             Çayırbaşı    6
# 32               İstinye    8

# %%
gym_venues = gym_venues.set_index('Neighborhood').join(ıstanbul_br.set_index('Neighborhood'))

gym_venues=gym_venues.reset_index()

gym_venues=gym_venues.drop(['City','District','Latitude','Longitude'],axis=1)


gym_venues
# Out:
#             Neighborhood  Gym Population
# 0         Bahçeköy Kemer    6       2296
# 1        Bahçeköy Merkez    7       3773
# 2          Bahçeköy Yeni    7       5135
# 3            Baltalimanı   16       5122
# 4              Büyükdere    5       8719
# 5             Cumhuriyet    9      10887
# 6            Darüşşafaka   23       9423
# 7             Demirciköy    1       1308
# 8                Emirgan    1       8751
# 9    Fatih Sultan Mehmet   25      15557
# 10            Ferahevler   26      14991
# 11                 Huzur   21       8020
# 12  Kazım Karabekir Paşa    1       7998
# 13                Kilyos    6       3465
# 14            Kireçburnu    8       6986
# 15               Kocataş    7       4383
# 16                 Maden   11      13260
# 17                Maslak   18       9567
# 18               Poligon   24       6667
# 19            Ptt Evleri    2       5342
# 20                 Pınar   30      11248
# 21             Reşitpaşa   11      17902
# 22          Rumelihisarı   16      10736
# 23          Rumelikavağı    7       3722
# 24        Sarıyer Merkez    6      12568
# 25               Tarabya   12      17724
# 26            Uskumruköy    1       8482
# 27                  Yeni    7       3400
# 28               Yeniköy    4      15218
# 29           Zekeriyaköy    5      18707
# 30             Çamlıtepe   17       5950
# 31             Çayırbaşı    6       4905
# 32               İstinye    8      15692

# %%
# We add "score" column to the data frame. 
gym_venues['score'] = gym_venues['Population'] / gym_venues['Gym']

# %%
# we change the name of column for a better understanding.
gym_venues.rename(columns={'Gym':'Number of Gyms'}, inplace=True)

# we sort score values in ascending order.
gym_venues.sort_values('score', ascending=False).reset_index(drop=True)
# Out:
#             Neighborhood  Number of Gyms Population    score
# 0                Emirgan               1       8751     8751
# 1             Uskumruköy               1       8482     8482
# 2   Kazım Karabekir Paşa               1       7998     7998
# 3                Yeniköy               4      15218   3804.5
# 4            Zekeriyaköy               5      18707   3741.4
# 5             Ptt Evleri               2       5342     2671
# 6         Sarıyer Merkez               6      12568  2094.67
# 7                İstinye               8      15692   1961.5
# 8              Büyükdere               5       8719   1743.8
# 9              Reşitpaşa              11      17902  1627.45
# 10               Tarabya              12      17724     1477
# 11            Demirciköy               1       1308     1308
# 12            Cumhuriyet               9      10887  1209.67
# 13                 Maden              11      13260  1205.45
# 14            Kireçburnu               8       6986   873.25
# 15             Çayırbaşı               6       4905    817.5
# 16         Bahçeköy Yeni               7       5135  733.571
# 17          Rumelihisarı              16      10736      671
# 18               Kocataş               7       4383  626.143
# 19   Fatih Sultan Mehmet              25      15557   622.28
# 20                Kilyos               6       3465    577.5
# 21            Ferahevler              26      14991  576.577
# 22       Bahçeköy Merkez               7       3773      539
# 23          Rumelikavağı               7       3722  531.714
# 24                Maslak              18       9567    531.5
# 25                  Yeni               7       3400  485.714
# 26           Darüşşafaka              23       9423  409.696
# 27        Bahçeköy Kemer               6       2296  382.667
# 28                 Huzur              21       8020  381.905
# 29                 Pınar              30      11248  374.933
# 30             Çamlıtepe              17       5950      350
# 31           Baltalimanı              16       5122  320.125
# 32               Poligon              24       6667  277.792

# %% [markdown]
# Descending order based on score. Less score >> Better result. For example, we have only one gym in Emirgan which could be a very good candidate for a new gym.
